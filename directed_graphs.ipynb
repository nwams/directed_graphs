# %% [markdown]
# ## Install networkx module

# %%
! pip install networkx
# Out:
# Requirement already satisfied (use --upgrade to upgrade): networkx in /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages
# Requirement already satisfied (use --upgrade to upgrade): decorator>=3.4.0 in /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages (from networkx)

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Import Data as Nodes Into Pandas df

# %%
fields = ['Actor1Code', 'Actor2Code']
df = pd.read_csv('query.csv', usecols=fields)

# %% [markdown]
# ## Replace all occurrance of PSEREB with PSE because both are: Palestine

# %%
df = df.replace('PSEREB', 'PSE')

# %% [markdown]
# ## Create a third column of tuples combining the Actor1Code & Actor2Code

# %%
df['Pairs'] = zip(df.Actor1Code, df.Actor2Code)

# %% [markdown]
# ## Add fourth column which counts pairs

# %%
df['CountPairs'] = df.groupby(['Pairs','Actor1Code']).transform('count')
df
# Out:
#     Actor1Code Actor2Code       Pairs  CountPairs
# 0          ISR        PSE  (ISR, PSE)         114
# 1          ISR        PSE  (ISR, PSE)         114
# 2          ISR        LBN  (ISR, LBN)          57
# 3          ISR        LBN  (ISR, LBN)          57
# 4          ISR        REB  (ISR, REB)          20
# 5          PSE        ISR  (PSE, ISR)          30
# 6          ISR        IRQ  (ISR, IRQ)           5
# 7          ISR        PSE  (ISR, PSE)         114
# 8          ISR        LBN  (ISR, LBN)          57
# 9          ISR        IRQ  (ISR, IRQ)           5
# 10         ITA        ISR  (ITA, ISR)           1
# 11         ISR        IRQ  (ISR, IRQ)           5
# 12         ISR        SYR  (ISR, SYR)          33
# 13         ISR        PSE  (ISR, PSE)         114
# 14         ISR        PSE  (ISR, PSE)         114
# 15         SYR        ISR  (SYR, ISR)          19
# 16         ISR        IRQ  (ISR, IRQ)           5
# 17         ISR        PSE  (ISR, PSE)         114
# 18         ISR        SYR  (ISR, SYR)          33
# 19         LBN        ISR  (LBN, ISR)          23
# 20         ISR        LBN  (ISR, LBN)          57
# 21         IRQ        ISR  (IRQ, ISR)           2
# 22         ISR        LBN  (ISR, LBN)          57
# 23         ISR        IRQ  (ISR, IRQ)           5
# 24         ISR        LBN  (ISR, LBN)          57
# 25         ISR        SYR  (ISR, SYR)          33
# 26         ISR        SYR  (ISR, SYR)          33
# 27         ISR        REB  (ISR, REB)          20
# 28         LBY        ISR  (LBY, ISR)           2
# 29         ISR        SYR  (ISR, SYR)          33
# ..         ...        ...         ...         ...
# 391        MIL        PSE  (MIL, PSE)           5
# 392        MIL        PSE  (MIL, PSE)           5
# 393        ISR        LBN  (ISR, LBN)          57
# 394        ISR        REB  (ISR, REB)          20
# 395        ISR        PSE  (ISR, PSE)         114
# 396        PSE        ISR  (PSE, ISR)          30
# 397        ISR        PSE  (ISR, PSE)         114
# 398        ISR        PSE  (ISR, PSE)         114
# 399        ISR        PSE  (ISR, PSE)         114
# 400        PSE        ISR  (PSE, ISR)          30
# 401        MIL        PSE  (MIL, PSE)           5
# 402        ISR        PSE  (ISR, PSE)         114
# 403        PSE        ISR  (PSE, ISR)          30
# 404        ISR        PSE  (ISR, PSE)         114
# 405        ISR        PSE  (ISR, PSE)         114
# 406        ISR        PSE  (ISR, PSE)         114
# 407        ISR        PSE  (ISR, PSE)         114
# 408        ISR        PSE  (ISR, PSE)         114
# 409        ISR        PSE  (ISR, PSE)         114
# 410        ISR        PSE  (ISR, PSE)         114
# 411        CVL        ISR  (CVL, ISR)           2
# 412        PSE        ISR  (PSE, ISR)          30
# 413        ISR        PSE  (ISR, PSE)         114
# 414        MIL        PSE  (MIL, PSE)           5
# 415        ISR        REB  (ISR, REB)          20
# 416        ISR        UAF  (ISR, UAF)           2
# 417        ISR        PSE  (ISR, PSE)         114
# 418        ISR        PSE  (ISR, PSE)         114
# 419        ISR        PSE  (ISR, PSE)         114
# 420        ISR        PSE  (ISR, PSE)         114
#
# [421 rows x 4 columns]

# %% [markdown]
# ## Enforce threshold of minimum interactions between countries

# %%
light_df = df[(df.CountPairs > 20)]
light_df
# Out:
#     Actor1Code Actor2Code       Pairs  CountPairs
# 0          ISR        PSE  (ISR, PSE)         114
# 1          ISR        PSE  (ISR, PSE)         114
# 2          ISR        LBN  (ISR, LBN)          57
# 3          ISR        LBN  (ISR, LBN)          57
# 5          PSE        ISR  (PSE, ISR)          30
# 7          ISR        PSE  (ISR, PSE)         114
# 8          ISR        LBN  (ISR, LBN)          57
# 12         ISR        SYR  (ISR, SYR)          33
# 13         ISR        PSE  (ISR, PSE)         114
# 14         ISR        PSE  (ISR, PSE)         114
# 17         ISR        PSE  (ISR, PSE)         114
# 18         ISR        SYR  (ISR, SYR)          33
# 19         LBN        ISR  (LBN, ISR)          23
# 20         ISR        LBN  (ISR, LBN)          57
# 22         ISR        LBN  (ISR, LBN)          57
# 24         ISR        LBN  (ISR, LBN)          57
# 25         ISR        SYR  (ISR, SYR)          33
# 26         ISR        SYR  (ISR, SYR)          33
# 29         ISR        SYR  (ISR, SYR)          33
# 30         ISR        SYR  (ISR, SYR)          33
# 31         ISR        PSE  (ISR, PSE)         114
# 34         PSE        ISR  (PSE, ISR)          30
# 36         ISR        PSE  (ISR, PSE)         114
# 38         ISR        SYR  (ISR, SYR)          33
# 40         ISR        SYR  (ISR, SYR)          33
# 42         ISR        PSE  (ISR, PSE)         114
# 44         ISR        SYR  (ISR, SYR)          33
# 45         ISR        SYR  (ISR, SYR)          33
# 49         ISR        PSE  (ISR, PSE)         114
# 51         ISR        SYR  (ISR, SYR)          33
# ..         ...        ...         ...         ...
# 378        ISR        PSE  (ISR, PSE)         114
# 379        ISR        PSE  (ISR, PSE)         114
# 380        ISR        PSE  (ISR, PSE)         114
# 382        ISR        PSE  (ISR, PSE)         114
# 384        PSE        ISR  (PSE, ISR)          30
# 385        ISR        PSE  (ISR, PSE)         114
# 387        PSE        ISR  (PSE, ISR)          30
# 390        ISR        PSE  (ISR, PSE)         114
# 393        ISR        LBN  (ISR, LBN)          57
# 395        ISR        PSE  (ISR, PSE)         114
# 396        PSE        ISR  (PSE, ISR)          30
# 397        ISR        PSE  (ISR, PSE)         114
# 398        ISR        PSE  (ISR, PSE)         114
# 399        ISR        PSE  (ISR, PSE)         114
# 400        PSE        ISR  (PSE, ISR)          30
# 402        ISR        PSE  (ISR, PSE)         114
# 403        PSE        ISR  (PSE, ISR)          30
# 404        ISR        PSE  (ISR, PSE)         114
# 405        ISR        PSE  (ISR, PSE)         114
# 406        ISR        PSE  (ISR, PSE)         114
# 407        ISR        PSE  (ISR, PSE)         114
# 408        ISR        PSE  (ISR, PSE)         114
# 409        ISR        PSE  (ISR, PSE)         114
# 410        ISR        PSE  (ISR, PSE)         114
# 412        PSE        ISR  (PSE, ISR)          30
# 413        ISR        PSE  (ISR, PSE)         114
# 417        ISR        PSE  (ISR, PSE)         114
# 418        ISR        PSE  (ISR, PSE)         114
# 419        ISR        PSE  (ISR, PSE)         114
# 420        ISR        PSE  (ISR, PSE)         114
#
# [257 rows x 4 columns]

# %%
G = nx.DiGraph() # directed graph
G.clear() # clear all lingering nodes

# %% [markdown]
# ## Build a directed graph from this data using Python networkx

# %%
for r in light_df.values:
    G.add_edge(r[0],r[1], weight=r[3])

# %%
plt.figure(figsize=(5,10));
plt.title('GDELT Project: Israel-Palestine conflicts, from 1979-1989.', fontsize=20, fontweight='bold')

nx.draw_networkx(G, with_labels=True, font_size=16, arrows=True, node_color='w', edge_color='k', alpha=0.6)

# %% [markdown]
# ## Pagerank

# %%
print nx.pagerank(G)
# Out:
# {'ISR': 0.4370266520236007, 'LBN': 0.16762748523957166, 'SYR': 0.12392501814307397, 'PSE': 0.2714208445937537}
